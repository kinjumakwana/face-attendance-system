#      -------------------------- ------------ 24.6/35.6 MB 26.2 MB/s eta 0:00:01
#      ---------------------------- ---------- 25.8/35.6 MB 26.2 MB/s eta 0:00:01
#      ----------------------------- --------- 27.0/35.6 MB 26.2 MB/s eta 0:00:01
#      ------------------------------ -------- 28.3/35.6 MB 26.2 MB/s eta 0:00:01
#      -------------------------------- ------ 29.3/35.6 MB 25.2 MB/s eta 0:00:01
#      --------------------------------- ----- 30.6/35.6 MB 25.1 MB/s eta 0:00:01
#      ---------------------------------- ---- 31.8/35.6 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------ -- 33.1/35.6 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------- - 34.3/35.6 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------  35.5/35.6 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------  35.6/35.6 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------  35.6/35.6 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------  35.6/35.6 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------  35.6/35.6 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------- 35.6/35.6 MB 16.4 MB/s eta 0:00:00
# Collecting Pillow==9.2.0 (from -r requirements_windows.txt (line 4))
#   Using cached Pillow-9.2.0-cp311-cp311-win_amd64.whl (3.3 MB)
# Collecting face_recognition==1.3.0 (from -r requirements_windows.txt (line 5))
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from opencv-python==4.6.0.66->-r requirements_windows.txt (line 3)) (1.26.0)
# Collecting face-recognition-models>=0.3.0 (from face_recognition==1.3.0->-r requirements_windows.txt (line 5))
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ---------------------------------------- 0.0/100.1 MB ? eta -:--:--
#       -------------------------------------- 1.8/100.1 MB 38.3 MB/s eta 0:00:03
#      - ------------------------------------- 3.9/100.1 MB 41.1 MB/s eta 0:00:03
#      - ------------------------------------- 4.9/100.1 MB 34.5 MB/s eta 0:00:03
#      -- ------------------------------------ 6.4/100.1 MB 34.1 MB/s eta 0:00:03
#      --- ----------------------------------- 8.6/100.1 MB 36.7 MB/s eta 0:00:03
#      --- ---------------------------------- 10.2/100.1 MB 36.1 MB/s eta 0:00:03
#      ---- --------------------------------- 11.4/100.1 MB 32.8 MB/s eta 0:00:03
#      ---- --------------------------------- 12.7/100.1 MB 32.7 MB/s eta 0:00:03
#      ----- -------------------------------- 13.9/100.1 MB 29.7 MB/s eta 0:00:03
#      ----- -------------------------------- 15.0/100.1 MB 29.7 MB/s eta 0:00:03
#      ------ ------------------------------- 16.3/100.1 MB 29.7 MB/s eta 0:00:03
#      ------ ------------------------------- 17.4/100.1 MB 29.7 MB/s eta 0:00:03
#      ------- ------------------------------ 18.7/100.1 MB 26.2 MB/s eta 0:00:04
#      ------- ------------------------------ 20.0/100.1 MB 25.2 MB/s eta 0:00:04
#      -------- ----------------------------- 21.2/100.1 MB 25.2 MB/s eta 0:00:04
#      -------- ----------------------------- 22.4/100.1 MB 26.2 MB/s eta 0:00:03
#      -------- ----------------------------- 23.6/100.1 MB 25.2 MB/s eta 0:00:04
#      --------- ---------------------------- 24.9/100.1 MB 26.2 MB/s eta 0:00:03
#      --------- ---------------------------- 26.1/100.1 MB 25.1 MB/s eta 0:00:03
#      ---------- --------------------------- 27.3/100.1 MB 26.2 MB/s eta 0:00:03
#      ---------- --------------------------- 28.6/100.1 MB 26.2 MB/s eta 0:00:03
#      ----------- -------------------------- 29.6/100.1 MB 25.2 MB/s eta 0:00:03
#      ----------- -------------------------- 31.2/100.1 MB 26.2 MB/s eta 0:00:03
#      ------------ ------------------------- 32.4/100.1 MB 26.2 MB/s eta 0:00:03
100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------- ------ 82.4/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------- ------ 83.7/100.1 MB 26.2 MB/s eta 0:00:01
#      -------------------------------- ----- 84.9/100.1 MB 26.2 MB/s eta 0:00:01
#      -------------------------------- ----- 85.9/100.1 MB 25.2 MB/s eta 0:00:01
#      --------------------------------- ---- 87.2/100.1 MB 25.2 MB/s eta 0:00:01
#      --------------------------------- ---- 88.3/100.1 MB 25.2 MB/s eta 0:00:01
#      --------------------------------- ---- 89.6/100.1 MB 25.1 MB/s eta 0:00:01
#      ---------------------------------- --- 90.8/100.1 MB 25.1 MB/s eta 0:00:01
#      ---------------------------------- --- 92.0/100.1 MB 25.2 MB/s eta 0:00:01
#      ----------------------------------- -- 93.2/100.1 MB 26.2 MB/s eta 0:00:01
#      ----------------------------------- -- 94.4/100.1 MB 25.2 MB/s eta 0:00:01
#      ------------------------------------ - 95.6/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------ - 96.8/100.1 MB 26.2 MB/s eta 0:00:01
#      -------------------------------------  98.1/100.1 MB 26.2 MB/s eta 0:00:01
#      -------------------------------------  99.2/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      ------------------------------------  100.1/100.1 MB 26.2 MB/s eta 0:00:01
#      -------------------------------------- 100.1/100.1 MB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Click>=6.0 (from face_recognition==1.3.0->-r requirements_windows.txt (line 5))
#   Obtaining dependency information for Click>=6.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from Click>=6.0->face_recognition==1.3.0->-r requirements_windows.txt (line 5)) (0.4.6)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# Building wheels for collected packages: dlib, face-recognition-models
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
#   Building wheel for face-recognition-models (setup.py): started
#   Building wheel for face-recognition-models (setup.py): finished with status 'done'
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566184 sha256=18a7dda7d21eae31df94da0d21d34f2bfe8189af47671431de9c44d28fcfce7b
#   Stored in directory: c:\users\baps\appdata\local\pip\cache\wheels\04\52\ec\9355da79c29f160b038a20c784db2803c2f9fa2c8a462c176a
# Successfully built face-recognition-models
# Failed to build dlib
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [68 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   running build_ext
#   Traceback (most recent call last):
#     File "C:\Users\BAPS\AppData\Local\Temp\pip-install-vj1cmqkg\dlib_d6bb94496620477eb3018720ba733ebd\setup.py", line 120, in get_cmake_version
#       out = subprocess.check_output(['cmake', '--version'])
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\subprocess.py", line 466, in check_output
#       return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\subprocess.py", line 548, in run
#       with Popen(*popenargs, **kwargs) as process:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\subprocess.py", line 1026, in __init__
#       self._execute_child(args, executable, preexec_fn, close_fds,
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\subprocess.py", line 1538, in _execute_child
#       hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   FileNotFoundError: [WinError 2] The system cannot find the file specified
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\BAPS\AppData\Local\Temp\pip-install-vj1cmqkg\dlib_d6bb94496620477eb3018720ba733ebd\setup.py", line 223, in <module>
#       setup(
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\__init__.py", line 107, in setup
#       return distutils.core.setup(**attrs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#              ^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\wheel\bdist_wheel.py", line 364, in run
#       self.run_command("build")
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\command\build.py", line 131, in run
#       self.run_command(cmd_name)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\dist.py", line 1234, in run_command
#       super().run_command(command)
#     File "C:\Users\BAPS\anaconda3\envs\yolo\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\BAPS\AppData\Local\Temp\pip-install-vj1cmqkg\dlib_d6bb94496620477eb3018720ba733ebd\setup.py", line 129, in run
#       cmake_version = self.get_cmake_version()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\BAPS\AppData\Local\Temp\pip-install-vj1cmqkg\dlib_d6bb94496620477eb3018720ba733ebd\setup.py", line 122, in get_cmake_version
#       raise RuntimeError("\n*******************************************************************\n" +
#   RuntimeError:
#   *******************************************************************
#    CMake must be installed to build the following extensions: dlib
#   *******************************************************************
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects

# %%
# !pip install face_recognition==1.3.0
# Out:
# Collecting face_recognition==1.3.0
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition==1.3.0)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Click>=6.0 (from face_recognition==1.3.0)
#   Obtaining dependency information for Click>=6.0 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting dlib>=19.7 (from face_recognition==1.3.0)
#   Using cached dlib-19.24.2.tar.gz (11.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from face_recognition==1.3.0) (1.26.0)
# Requirement already satisfied: Pillow in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from face_recognition==1.3.0) (10.0.1)
# Requirement already satisfied: colorama in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from Click>=6.0->face_recognition==1.3.0) (0.4.6)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): still running...
#   Building wheel for dlib (pyproject.toml): still running...
#   Building wheel for dlib (pyproject.toml): still running...
#   Building wheel for dlib (pyproject.toml): still running...
#   Building wheel for dlib (pyproject.toml): finished with status 'done'
#   Created wheel for dlib: filename=dlib-19.24.2-cp311-cp311-win_amd64.whl size=2835782 sha256=776f68304cbe61b341f5af6e88ffd64ba7c7c04906ea8a63c5566fef5bf7ace2
#   Stored in directory: c:\users\baps\appdata\local\pip\cache\wheels\61\05\62\44b0bf18a0f8f9a0d65337b11237ecf12926d0d6e3807500bb
# Successfully built dlib
# Installing collected packages: face-recognition-models, dlib, Click, face_recognition
# Successfully installed Click-8.1.7 dlib-19.24.2 face-recognition-models-0.3.0 face_recognition-1.3.0

# %%
# !pip list
# Out:
# Package                 Version
# ----------------------- --------------------
# absl-py                 2.0.0
# antlr4-python3-runtime  4.9.3
# anyio                   3.5.0
# argon2-cffi             21.3.0
# argon2-cffi-bindings    21.2.0
# asttokens               2.0.5
# attrs                   23.1.0
# backcall                0.2.0
# beautifulsoup4          4.12.2
# bleach                  4.1.0
# cachetools              5.3.1
# certifi                 2023.7.22
# cffi                    1.15.1
# chardet                 5.2.0
# charset-normalizer      3.3.0
# click                   8.1.7
# clip                    1.0
# colorama                0.4.6
# coloredlogs             15.0.1
# comm                    0.1.2
# contourpy               1.1.1
# cycler                  0.12.0
# Cython                  3.0.2
# debugpy                 1.6.7
# decorator               5.1.1
# deep-sort-realtime      1.3.2
# defusedxml              0.7.1
# dlib                    19.24.2
# easydict                1.10
# entrypoints             0.4
# executing               0.8.3
# face-recognition        1.3.0
# face-recognition-models 0.3.0
# fastjsonschema          2.16.2
# filelock                3.12.4
# flake8                  6.1.0
# flatbuffers             23.5.26
# fonttools               4.43.0
# ftfy                    6.1.1
# future                  0.18.3
# gdown                   4.7.1
# gitdb                   4.0.10
# GitPython               3.1.37
# google-auth             2.23.2
# google-auth-oauthlib    1.0.0
# grpcio                  1.59.0
# h5py                    3.9.0
# humanfriendly           10.0
# hydra-core              1.3.2
# idna                    3.4
# imageio                 2.31.5
# importlib-metadata      6.8.0
# imutils                 0.5.4
# ipykernel               6.25.0
# ipython                 8.15.0
# ipython-genutils        0.2.0
# isort                   4.3.21
# jedi                    0.18.1
# Jinja2                  3.1.2
# jsonschema              4.17.3
# jupyter_client          7.4.9
# jupyter_core            5.3.0
# jupyter-server          1.23.4
# jupyterlab-pygments     0.1.2
# kiwisolver              1.4.5
# lapx                    0.5.4
# lxml                    4.9.3
# Markdown                3.4.4
# MarkupSafe              2.1.1
# matplotlib              3.8.0
# matplotlib-inline       0.1.6
# mccabe                  0.7.0
# mistune                 0.8.4
# mock                    5.1.0
# mpmath                  1.3.0
# nbclassic               0.5.5
# nbclient                0.5.13
# nbconvert               6.5.4
# nbformat                5.9.2
# nest-asyncio            1.5.6
# networkx                3.1
# notebook                6.5.4
# notebook_shim           0.2.2
# numpy                   1.26.0
# oauthlib                3.2.2
# omegaconf               2.3.0
# onnxruntime             1.16.0
# opencv-python           4.8.1.78
# packaging               23.1
# pandas                  2.1.1
# pandocfilters           1.5.0
# parso                   0.8.3
# pickleshare             0.7.5
# Pillow                  10.0.1
# pip                     23.2.1
# platformdirs            3.10.0
# prometheus-client       0.14.1
# prompt-toolkit          3.0.36
# protobuf                4.23.4
# psutil                  5.9.0
# pure-eval               0.2.2
# py-cpuinfo              9.0.0
# pyasn1                  0.5.0
# pyasn1-modules          0.3.0
# pycodestyle             2.11.0
# pycparser               2.21
# pyflakes                3.1.0
# Pygments                2.15.1
# pyparsing               3.1.1
# pyreadline3             3.4.1
# pyrsistent              0.18.0
# PySocks                 1.7.1
# python-dateutil         2.8.2
# pytz                    2023.3.post1
# pywin32                 305.1
# pywinpty                2.0.10
# PyYAML                  6.0.1
# pyzmq                   23.2.0
# redis                   5.0.1
# regex                   2023.10.3
# requests                2.31.0
# requests-oauthlib       1.3.1
# rsa                     4.9
# scipy                   1.11.3
# seaborn                 0.13.0
# Send2Trash              1.8.0
# setuptools              68.0.0
# six                     1.16.0
# smmap                   5.0.1
# sniffio                 1.2.0
# soupsieve               2.4
# stack-data              0.2.0
# sympy                   1.12
# tb-nightly              2.15.0a20231003
# tensorboard             2.14.1
# tensorboard-data-server 0.7.1
# terminado               0.17.1
# thop                    0.1.1.post2209072238
# tinycss2                1.2.1
# tomli                   2.0.1
# torch                   2.0.1
# torchaudio              2.0.2
# torchvision             0.15.2
# tornado                 6.3.2
# tqdm                    4.66.1
# traitlets               5.7.1
# typing_extensions       4.7.1
# tzdata                  2023.3
# ultralytics             8.0.191
# urllib3                 2.0.6
# wcwidth                 0.2.5
# webencodings            0.5.1
# websocket-client        0.58.0
# Werkzeug                3.0.0
# wheel                   0.41.2
# yacs                    0.1.8
# yapf                    0.40.2
# zipp                    3.17.0

# %%
# !git clone https://github.com/computervisioneng/Silent-Face-Anti-Spoofing.git
# !pip install -r requirements.txt
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.1 (from versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3, 0.15.0, 0.15.1, 0.15.2, 0.16.0)
# ERROR: No matching distribution found for torchvision==0.14.1
# Requirement already satisfied: easydict==1.10 in c:\users\baps\anaconda3\envs\yolo\lib\site-packages (from -r requirements.txt (line 1)) (1.10)
# Collecting numpy==1.23.5 (from -r requirements.txt (line 2))
#   Using cached numpy-1.23.5-cp311-cp311-win_amd64.whl (14.6 MB)
# Collecting tqdm==4.64.1 (from -r requirements.txt (line 3))
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)

# %%
# !python main.py
# Out:
# ^C
